',
#  'Why?',
#  'Because we respect the freedom of others.',
#  'That is why my first vision is freedom.',
#  'If we are not free, no one will respect us.',
# ...

# %%
from nltk import SnowballStemmer

# %%
sentences = nltk.sent_tokenize(paragraph)

# %%
## Apply Stopwords and filter and then  apply snowball stemming


for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    snowball = SnowballStemmer("english")

    for i in range(len(sentences)):
        words = nltk.word_tokenize(sentences[i])
        words = [snowball.stem(word) for word in words if word.lower() not in set(stopwords.words('english'))]
        sentences[i] = ' '.join(words)
sentences[i]= ''.join(words) #converting all words into sentences.

# %%
sentences
# Out:
# ['famous motiv speech former presid * * dr. a. p. j. abdul kalam * * vision india , adapt approxim 500 word : * * * * * “ vision india ” – speech dr. a. p. j. abdul kalam * * ( iit hyderabad , 2011 ) good morn — dear student , respect teacher , fellow citizen .',
#  'today , want share vision india .',
#  'vision grow mind mani year , believ vision nation need becom develop countri year 2020 .',
#  '* * first vision freedom .',
#  '* * believ india got first vision freedom 1857 , start war independ .',
#  'yet , conquer nation .',
#  'grab land , cultur , histori .',
#  '?',
#  'respect freedom .',
#  'first vision freedom .',
#  'free , one respect us .',
#  'must protect nurtur freedom .',
#  '* * second vision india develop .',
#  '* * fifti year , call “ develop nation . ” time see * develop * nation .',
#  'among top five nation world term gdp .',
#  'poverti level fall .',
#  'achiev global recogn today .',
#  'yet , lack self-confid see develop nation , self-r self-assur .',
# ...

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
## Apply Stopwords and filter and then  apply lemmatizing 


for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    snowball = SnowballStemmer("english")

    for i in range(len(sentences)):
        words = nltk.word_tokenize(sentences[i])
        words = [lemmatizer.lemmatize(word) for word in words if word.lower() not in set(stopwords.words('english'))]
        sentences[i] = ' '.join(words)
sentences[i]= ''.join(words) #converting all words into sentences.

# %%
sentences
# Out:
# ['famous motivational speech former President * * Dr. A. P. J. Abdul Kalam * * vision India , adapted approximately 500 word : * * * * * “ Vision India ” – Speech Dr. A. P. J. Abdul Kalam * * ( IIT Hyderabad , 2011 ) Good morning — dear student , respected teacher , fellow citizen .',
#  'Today , want share vision India .',
#  'vision growing mind many year , believe vision nation need become developed country year 2020 .',
#  '* * first vision FREEDOM .',
#  '* * believe India got first vision freedom 1857 , started War Independence .',
#  'Yet , conquered nation .',
#  'grabbed land , culture , history .',
#  '?',
#  'respect freedom others .',
#  'first vision freedom .',
#  'free , one respect u .',
#  'must protect nurture freedom .',
#  '* * second vision India DEVELOPMENT .',
#  '* * fifty year , called “ developing nation . ” time see * developed * nation .',
#  'among top five nation world term GDP .',
#  'poverty level falling .',
# ...
