# %%
import array as arr

# %%
A = arr.array("i",[11,12,13,14,15])
print(A[:]) #complete arrary

# %%
import array as arr
A = arr.array("i",[10,11,12,14,15,18,19,20])
A.insert(100,200)

# %%
print(A[:])
# Out:
# array('i', [10, 11, 12, 14, 15, 18, 19, 20, 200])

# %%
B = arr.array("i",[200,300,400,500,600,700,800])
print(B[:])
# Out:
# array('i', [200, 300, 400, 500, 600, 700, 800])

# %%
B.append(1000)

# %%
print(B[:])
# Out:
# array('i', [200, 300, 400, 500, 600, 700, 800, 1000])

# %%
B[:]
# Out:
# array('i', [200, 300, 400, 500, 600, 700, 800, 1000])

# %%
B.extend([1,2,3,4,4,55])
B[:]
# Out:
# array('i', [200, 300, 400, 500, 600, 700, 800, 1000, 1, 2, 3, 4, 4, 55])
