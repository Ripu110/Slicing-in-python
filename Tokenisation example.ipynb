# %%
# %pip install NLTK
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
corpus=""" Hello welcome,to krish naik tutorials.please do watch the netire course."""

# %%
print(corpus)
# Out:
#  Hello welcome,to krish naik tutorials.please do watch the netire course.

# %%
## Tokenisation 
## sentences --> paragraphs
from nltk.tokenize import sent_tokenize

# %%
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize
sent_tokenize(corpus)
# Out:
# [' Hello welcome,to krish naik tutorials.please do watch the netire course.']

# %%
document = corpus1 = """this a new! marking day and have a nice day. this ia a python program. you can go to london today itself. today is momday's morning"""

# %% [markdown]
# sent_tokenize takes exclamatory mark a new sentence or a new line.

# %%
sent_tokenize(document)
# Out:
# ['this a new!',
#  'marking day and have a nice day.',
#  'this ia a python program.',
#  'you can go to london today itself.',
#  "today is momday's morning"]

# %%
type(document)
# Out:
# str

# %%
for sentence in document:
    print(word_tokenize(sentence))
    #print("\n".join(sent_tokenize(sentence)))
# Out:
# ['t']
# ['h']
# ['i']
# ['s']
# []
# ['a']
# []
# ['n']
# ['e']
# ['w']
# ['!']
# []
# ['m']
# ['a']
# ['r']
# ['k']
# ['i']
# ['n']
# ['g']
# []
# ['d']
# ['a']
# ['y']
# []
# ['a']
# ['n']
# ['d']
# []
# ['h']
# ['a']
# ['v']
# ['e']
# []
# ['a']
# []
# ['n']
# ['i']
# ['c']
# ['e']
# []
# ['d']
# ['a']
# ['y']
# ['.']
# []
# ['t']
# ['h']
# ['i']
# ['s']
# []
# ['i']
# ['a']
# []
# ['a']
# []
# ['p']
# ['y']
# ['t']
# ['h']
# ['o']
# ['n']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['a']
# ['m']
# ['.']
# []
# ['y']
# ['o']
# ['u']
# []
# ['c']
# ['a']
# ['n']
# []
# ['g']
# ['o']
# []
# ['t']
# ['o']
# []
# ['l']
# ['o']
# ['n']
# ['d']
# ['o']
# ['n']
# []
# ['t']
# ['o']
# ['d']
# ['a']
# ['y']
# []
# ['i']
# ['t']
# ['s']
# ['e']
# ['l']
# ['f']
# ['.']
# []
# ['t']
# ['o']
# ['d']
# ['a']
# ['y']
# []
# ['i']
# ['s']
# []
# ['m']
# ['o']
# ['m']
# ['d']
# ['a']
# ['y']
# ["'"]
# ['s']
# []
# ['m']
# ['o']
# ['r']
# ['n']
# ['i']
# ['n']
# ['g']

# %%
## tokensisation
## paragraphs --> words
## sentence --> words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus1)
# Out:
# ['this',
#  'a',
#  'new',
#  '!',
#  'marking',
#  'day',
#  'and',
#  'have',
#  'a',
#  'nice',
#  'day',
#  '.',
#  'this',
#  'ia',
#  'a',
#  'python',
#  'program',
#  '.',
#  'you',
#  'can',
#  'go',
#  'to',
#  'london',
#  'today',
#  'itself',
#  '.',
#  'today',
#  'is',
#  'momday',
#  "'s",
#  'morning']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus1)
# Out:
# ['this',
#  'a',
#  'new',
#  '!',
#  'marking',
#  'day',
#  'and',
#  'have',
#  'a',
#  'nice',
#  'day',
#  '.',
#  'this',
#  'ia',
#  'a',
#  'python',
#  'program',
#  '.',
#  'you',
#  'can',
#  'go',
#  'to',
#  'london',
#  'today',
#  'itself',
#  '.',
#  'today',
#  'is',
#  'momday',
#  "'",
#  's',
#  'morning']

# %%
from nltk import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()
document = corpus1 = """this a new! marking day and have a nice day. this ia a python program. you can go to london today itself. today is momday's morning."""

# %%
tokenizer.tokenize(corpus1)
# Out:
# ['this',
#  'a',
#  'new',
#  '!',
#  'marking',
#  'day',
#  'and',
#  'have',
#  'a',
#  'nice',
#  'day.',
#  'this',
#  'ia',
#  'a',
#  'python',
#  'program.',
#  'you',
#  'can',
#  'go',
#  'to',
#  'london',
#  'today',
#  'itself.',
#  'today',
#  'is',
#  'momday',
#  "'s",
#  'morning',
#  '.']

# %% [markdown]
# #revisit for the periods that are not been separated with words.
